# %% [markdown]
# # Proceso de análisis y limpieza de datos

# %% [markdown]
# En este curso conoceremos, exploraremos y limpiaremos nuestro set de datos antes de imputarlos.
#
# En este caso examinaremos NHANES.
#
# ## Preparando datos: _National Health and Nutrition Examination Survey_

# %% [markdown]
# ## Importar librerías

# %%
import janitor
import nhanes.load
import numpy as np
import pandas as pd
import missingno
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/nhanes/load.py:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %% [markdown]
# ## Importar funciones personalizadas

# %%
# %run pandas-missing-extension-re.ipynb

# %% [markdown]
# ## Cargar los datos de NHANES

# %%
(
    nhanes.load.load_NHANES_data(year="2017-2018")
)
# Out:
#          GeneralHealthCondition  EverBreastfedOrFedBreastmilk  \
# SEQN
# 93703.0                     NaN                           1.0
# 93704.0                     NaN                           1.0
# 93705.0                    Good                           NaN
# 93706.0               Very good                           NaN
# 93707.0                    Good                           NaN
# ...                         ...                           ...
# 102952.0              Very good                           NaN
# 102953.0                Fair or                           NaN
# 102954.0                   Good                           NaN
# 102955.0              Very good                           NaN
# 102956.0                   Good                           NaN
#
#           AgeStoppedBreastfeedingdays  AgeFirstFedFormuladays  \
# SEQN
# 93703.0                         273.0                     1.0
# 93704.0                          60.0                     3.0
# 93705.0                           NaN                     NaN
# 93706.0                           NaN                     NaN
# 93707.0                           NaN                     NaN
# ...                               ...                     ...
# 102952.0                          NaN                     NaN
# 102953.0                          NaN                     NaN
# 102954.0                          NaN                     NaN
# 102955.0                          NaN                     NaN
# 102956.0                          NaN                     NaN
#
#           AgeStoppedReceivingFormuladays  AgeStartedOtherFoodbeverage  \
# SEQN
# 93703.0                            365.0                        152.0
# 93704.0                            365.0                        126.0
# 93705.0                              NaN                          NaN
# 93706.0                              NaN                          NaN
# 93707.0                              NaN                          NaN
# ...                                  ...                          ...
# 102952.0                             NaN                          NaN
# 102953.0                             NaN                          NaN
# 102954.0                             NaN                          NaN
# 102955.0                             NaN                          NaN
# 102956.0                             NaN                          NaN
#
#           AgeFirstFedMilkdays TypeOfMilkFirstFedWholeMilk  \
# SEQN
# 93703.0                 365.0       Whole or regular milk
# 93704.0                 365.0       Whole or regular milk
# 93705.0                   NaN                         NaN
# 93706.0                   NaN                         NaN
# 93707.0                   NaN                         NaN
# ...                       ...                         ...
# 102952.0                  NaN                         NaN
# 102953.0                  NaN                         NaN
# 102954.0                  NaN                         NaN
# 102955.0                  NaN                         NaN
# 102956.0                  NaN                         NaN
#
#           TypeOfMilkFirstFed2Milk  TypeOfMilkFirstFed1Milk  ...  \
# SEQN                                                        ...
# 93703.0                       NaN                      NaN  ...
# 93704.0                       NaN                      NaN  ...
# 93705.0                       NaN                      NaN  ...
# 93706.0                       NaN                      NaN  ...
# 93707.0                       NaN                      NaN  ...
# ...                           ...                      ...  ...
# 102952.0                      NaN                      NaN  ...
# 102953.0                      NaN                      NaN  ...
# 102954.0                      NaN                      NaN  ...
# 102955.0                      NaN                      NaN  ...
# 102956.0                      NaN                      NaN  ...
#
#           DaysSmokedCigsDuringPast30Days  AvgCigarettesdayDuringPast30Days  \
# SEQN
# 93703.0                              NaN                               NaN
# 93704.0                              NaN                               NaN
# 93705.0                              NaN                               NaN
# 93706.0                              NaN                               NaN
# 93707.0                              NaN                               NaN
# ...                                  ...                               ...
# 102952.0                             NaN                               NaN
# 102953.0                             NaN                               NaN
# 102954.0                             NaN                               NaN
# 102955.0                             NaN                               NaN
# 102956.0                            30.0                              20.0
#
#           TriedToQuitSmoking TimesStoppedSmokingCigarettes  \
# SEQN
# 93703.0                  NaN                           NaN
# 93704.0                  NaN                           NaN
# 93705.0                  NaN                           NaN
# 93706.0                  NaN                           NaN
# 93707.0                  NaN                           NaN
# ...                      ...                           ...
# 102952.0                 NaN                           NaN
# 102953.0                 NaN                           NaN
# 102954.0                 NaN                           NaN
# 102955.0                 NaN                           NaN
# 102956.0                 1.0                           1.0
#
#          HowLongWereYouAbleToStopSmoking UnitOfMeasureDayweekmonthyear_2_SMQ  \
# SEQN
# 93703.0                              NaN                                 NaN
# 93704.0                              NaN                                 NaN
# 93705.0                              NaN                                 NaN
# 93706.0                              NaN                                 NaN
# 93707.0                              NaN                                 NaN
# ...                                  ...                                 ...
# 102952.0                             NaN                                 NaN
# 102953.0                             NaN                                 NaN
# 102954.0                             NaN                                 NaN
# 102955.0                             NaN                                 NaN
# 102956.0                             2.0                                Days
#
#           CurrentSelfreportedHeightInches  CurrentSelfreportedWeightPounds  \
# SEQN
# 93703.0                               NaN                              NaN
# 93704.0                               NaN                              NaN
# 93705.0                              63.0                            165.0
# 93706.0                              68.0                            145.0
# 93707.0                               NaN                              NaN
# ...                                   ...                              ...
# 102952.0                              NaN                            117.0
# 102953.0                             65.0                            218.0
# 102954.0                             66.0                            150.0
# 102955.0                              NaN                              NaN
# 102956.0                             69.0                            250.0
#
#           TriedToLoseWeightInPastYear  TimesLost10LbsOrMoreToLoseWeight
# SEQN
# 93703.0                           NaN                               NaN
# 93704.0                           NaN                               NaN
# 93705.0                           0.0                  11 times or more
# 93706.0                           0.0                             Never
# 93707.0                           NaN                               NaN
# ...                               ...                               ...
# 102952.0                          0.0                             Never
# 102953.0                          0.0                             Never
# 102954.0                          0.0                             Never
# 102955.0                          NaN                               NaN
# 102956.0                          0.0                            1 to 2
#
# [8366 rows x 197 columns]

# %% [markdown]
# Como se puede observar tenemos un total de:
# - 8366 filas
# - 197 columnas
#
# También podemos ver que podemos cambiar el encabezado de las columnas a un tipo diferente

# %%
(
    nhanes.load.load_NHANES_data(year="2017-2018")
    .clean_names(
        case_type='snake'
    )
)
# Out:
#          general_health_condition  ever_breastfed_or_fed_breastmilk  \
# SEQN
# 93703.0                       NaN                               1.0
# 93704.0                       NaN                               1.0
# 93705.0                      Good                               NaN
# 93706.0                 Very good                               NaN
# 93707.0                      Good                               NaN
# ...                           ...                               ...
# 102952.0                Very good                               NaN
# 102953.0                  Fair or                               NaN
# 102954.0                     Good                               NaN
# 102955.0                Very good                               NaN
# 102956.0                     Good                               NaN
#
#           age_stopped_breastfeedingdays  age_first_fed_formuladays  \
# SEQN
# 93703.0                           273.0                        1.0
# 93704.0                            60.0                        3.0
# 93705.0                             NaN                        NaN
# 93706.0                             NaN                        NaN
# 93707.0                             NaN                        NaN
# ...                                 ...                        ...
# 102952.0                            NaN                        NaN
# 102953.0                            NaN                        NaN
# 102954.0                            NaN                        NaN
# 102955.0                            NaN                        NaN
# 102956.0                            NaN                        NaN
#
#           age_stopped_receiving_formuladays  age_started_other_foodbeverage  \
# SEQN
# 93703.0                               365.0                           152.0
# 93704.0                               365.0                           126.0
# 93705.0                                 NaN                             NaN
# 93706.0                                 NaN                             NaN
# 93707.0                                 NaN                             NaN
# ...                                     ...                             ...
# 102952.0                                NaN                             NaN
# 102953.0                                NaN                             NaN
# 102954.0                                NaN                             NaN
# 102955.0                                NaN                             NaN
# 102956.0                                NaN                             NaN
#
#           age_first_fed_milkdays type_of_milk_first_fed_whole_milk  \
# SEQN
# 93703.0                    365.0             Whole or regular milk
# 93704.0                    365.0             Whole or regular milk
# 93705.0                      NaN                               NaN
# 93706.0                      NaN                               NaN
# 93707.0                      NaN                               NaN
# ...                          ...                               ...
# 102952.0                     NaN                               NaN
# 102953.0                     NaN                               NaN
# 102954.0                     NaN                               NaN
# 102955.0                     NaN                               NaN
# 102956.0                     NaN                               NaN
#
#           type_of_milk_first_fed2_milk  type_of_milk_first_fed1_milk  ...  \
# SEQN                                                                  ...
# 93703.0                            NaN                           NaN  ...
# 93704.0                            NaN                           NaN  ...
# 93705.0                            NaN                           NaN  ...
# 93706.0                            NaN                           NaN  ...
# 93707.0                            NaN                           NaN  ...
# ...                                ...                           ...  ...
# 102952.0                           NaN                           NaN  ...
# 102953.0                           NaN                           NaN  ...
# 102954.0                           NaN                           NaN  ...
# 102955.0                           NaN                           NaN  ...
# 102956.0                           NaN                           NaN  ...
#
#           days_smoked_cigs_during_past30_days  \
# SEQN
# 93703.0                                   NaN
# 93704.0                                   NaN
# 93705.0                                   NaN
# 93706.0                                   NaN
# 93707.0                                   NaN
# ...                                       ...
# 102952.0                                  NaN
# 102953.0                                  NaN
# 102954.0                                  NaN
# 102955.0                                  NaN
# 102956.0                                 30.0
#
#           avg_cigarettesday_during_past30_days  tried_to_quit_smoking  \
# SEQN
# 93703.0                                    NaN                    NaN
# 93704.0                                    NaN                    NaN
# 93705.0                                    NaN                    NaN
# 93706.0                                    NaN                    NaN
# 93707.0                                    NaN                    NaN
# ...                                        ...                    ...
# 102952.0                                   NaN                    NaN
# 102953.0                                   NaN                    NaN
# 102954.0                                   NaN                    NaN
# 102955.0                                   NaN                    NaN
# 102956.0                                  20.0                    1.0
#
#          times_stopped_smoking_cigarettes  \
# SEQN
# 93703.0                               NaN
# 93704.0                               NaN
# 93705.0                               NaN
# 93706.0                               NaN
# 93707.0                               NaN
# ...                                   ...
# 102952.0                              NaN
# 102953.0                              NaN
# 102954.0                              NaN
# 102955.0                              NaN
# 102956.0                              1.0
#
#          how_long_were_you_able_to_stop_smoking  \
# SEQN
# 93703.0                                     NaN
# 93704.0                                     NaN
# 93705.0                                     NaN
# 93706.0                                     NaN
# 93707.0                                     NaN
# ...                                         ...
# 102952.0                                    NaN
# 102953.0                                    NaN
# 102954.0                                    NaN
# 102955.0                                    NaN
# 102956.0                                    2.0
#
#          unit_of_measure_dayweekmonthyear_2_smq  \
# SEQN
# 93703.0                                     NaN
# 93704.0                                     NaN
# 93705.0                                     NaN
# 93706.0                                     NaN
# 93707.0                                     NaN
# ...                                         ...
# 102952.0                                    NaN
# 102953.0                                    NaN
# 102954.0                                    NaN
# 102955.0                                    NaN
# 102956.0                                   Days
#
#           current_selfreported_height_inches  \
# SEQN
# 93703.0                                  NaN
# 93704.0                                  NaN
# 93705.0                                 63.0
# 93706.0                                 68.0
# 93707.0                                  NaN
# ...                                      ...
# 102952.0                                 NaN
# 102953.0                                65.0
# 102954.0                                66.0
# 102955.0                                 NaN
# 102956.0                                69.0
#
#           current_selfreported_weight_pounds  \
# SEQN
# 93703.0                                  NaN
# 93704.0                                  NaN
# 93705.0                                165.0
# 93706.0                                145.0
# 93707.0                                  NaN
# ...                                      ...
# 102952.0                               117.0
# 102953.0                               218.0
# 102954.0                               150.0
# 102955.0                                 NaN
# 102956.0                               250.0
#
#           tried_to_lose_weight_in_past_year  \
# SEQN
# 93703.0                                 NaN
# 93704.0                                 NaN
# 93705.0                                 0.0
# 93706.0                                 0.0
# 93707.0                                 NaN
# ...                                     ...
# 102952.0                                0.0
# 102953.0                                0.0
# 102954.0                                0.0
# 102955.0                                NaN
# 102956.0                                0.0
#
#           times_lost10_lbs_or_more_to_lose_weight
# SEQN
# 93703.0                                       NaN
# 93704.0                                       NaN
# 93705.0                          11 times or more
# 93706.0                                     Never
# 93707.0                                       NaN
# ...                                           ...
# 102952.0                                    Never
# 102953.0                                    Never
# 102954.0                                    Never
# 102955.0                                      NaN
# 102956.0                                   1 to 2
#
# [8366 rows x 197 columns]

# %% [markdown]
# Ahora hemos separado las palabras con un "_", por lo que nos facilita la lectura.
#
# Ya que tenemos esto, necesariamente tenemos que guardarlo en un conjunto de datos, para después usarlo.

# %%
nhanes_raw_df = (
    nhanes.load.load_NHANES_data(year="2017-2018")
    .clean_names(
        case_type='snake'
    )
)
nhanes_raw_df.shape
# Out:
# (8366, 197)

# %% [markdown]
# ## Procesar el Data Frame

# %%
#Seleccionando un sub_conjunto de columnas
(
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )

)
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
#          general_health_condition  age_in_years_at_screening  gender  \
# SEQN
# 93703.0                       NaN                        2.0  Female
# 93704.0                       NaN                        2.0    Male
# 93705.0                      Good                       66.0  Female
# 93706.0                 Very good                       18.0    Male
# 93707.0                      Good                       13.0    Male
# ...                           ...                        ...     ...
# 102952.0                Very good                       70.0  Female
# 102953.0                  Fair or                       42.0    Male
# 102954.0                     Good                       41.0  Female
# 102955.0                Very good                       14.0  Female
# 102956.0                     Good                       38.0    Male
#
#           current_selfreported_height_inches  \
# SEQN
# 93703.0                                  NaN
# 93704.0                                  NaN
# 93705.0                                 63.0
# 93706.0                                 68.0
# 93707.0                                  NaN
# ...                                      ...
# 102952.0                                 NaN
# 102953.0                                65.0
# 102954.0                                66.0
# 102955.0                                 NaN
# 102956.0                                69.0
#
#           current_selfreported_weight_pounds doctor_told_you_have_diabetes  \
# SEQN
# 93703.0                                  NaN                             0
# 93704.0                                  NaN                             0
# 93705.0                                165.0                             0
# 93706.0                                145.0                             0
# 93707.0                                  NaN                             0
# ...                                      ...                           ...
# 102952.0                               117.0                    Borderline
# 102953.0                               218.0                             0
# 102954.0                               150.0                             0
# 102955.0                                 NaN                             0
# 102956.0                               250.0                             0
#
#           60_sec_pulse30_sec_pulse2  total_cholesterol_mgdl
# SEQN
# 93703.0                         NaN                     NaN
# 93704.0                         NaN                     NaN
# 93705.0                        52.0                   157.0
# 93706.0                        82.0                   148.0
# 93707.0                       100.0                   189.0
# ...                             ...                     ...
# 102952.0                       68.0                   119.0
# 102953.0                       78.0                   182.0
# 102954.0                       78.0                   172.0
# 102955.0                       74.0                   150.0
# 102956.0                       76.0                   163.0
#
# [8366 rows x 8 columns]

# %% [markdown]
# Una vez que hemos seleccionado las columnas, lo que necesitamos hacer ahora es renombrar las columnas, porque son nombres demasiado largos y difícil de recordar.

# %%
#Seleccionando un sub_conjunto de columnas
(
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )
    .rename_columns(
        {
            'age_in_years_at_screening':"age",
            'current_selfreported_height_inches':"height",
            'current_selfreported_weight_pounds':"weight",
            'doctor_told_you_have_diabetes':"diabetes",
            '60_sec_pulse30_sec_pulse2':"pulse",
            'total_cholesterol_mgdl':"cholesterol_mgdl"
        }
    )
)
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#          general_health_condition   age  gender  height  weight    diabetes  \
# SEQN
# 93703.0                       NaN   2.0  Female     NaN     NaN           0
# 93704.0                       NaN   2.0    Male     NaN     NaN           0
# 93705.0                      Good  66.0  Female    63.0   165.0           0
# 93706.0                 Very good  18.0    Male    68.0   145.0           0
# 93707.0                      Good  13.0    Male     NaN     NaN           0
# ...                           ...   ...     ...     ...     ...         ...
# 102952.0                Very good  70.0  Female     NaN   117.0  Borderline
# 102953.0                  Fair or  42.0    Male    65.0   218.0           0
# 102954.0                     Good  41.0  Female    66.0   150.0           0
# 102955.0                Very good  14.0  Female     NaN     NaN           0
# 102956.0                     Good  38.0    Male    69.0   250.0           0
#
#           pulse  cholesterol_mgdl
# SEQN
# 93703.0     NaN               NaN
# 93704.0     NaN               NaN
# 93705.0    52.0             157.0
# 93706.0    82.0             148.0
# 93707.0   100.0             189.0
# ...         ...               ...
# 102952.0   68.0             119.0
# 102953.0   78.0             182.0
# 102954.0   78.0             172.0
# 102955.0   74.0             150.0
# 102956.0   76.0             163.0
#
# [8366 rows x 8 columns]

# %% [markdown]
# ## Codificando valores faltantes

# %%
#Seleccionando un sub_conjunto de columnas
(
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )
    .rename_columns(
        {
            'age_in_years_at_screening':"age",
            'current_selfreported_height_inches':"height",
            'current_selfreported_weight_pounds':"weight",
            'doctor_told_you_have_diabetes':"diabetes",
            '60_sec_pulse30_sec_pulse2':"pulse",
            'total_cholesterol_mgdl':"cholesterol_mgdl"
        }
    )
    .replace(
        {
            'height':{
                9999:np.nan,
                7777:np.nan
            },
            'weight':{
                9999:np.nan,
                7777:np.nan
            },
            'diabetes':{
                'Borderline':np.nan
            }
        }
    )
)
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#          general_health_condition   age  gender  height  weight diabetes  \
# SEQN
# 93703.0                       NaN   2.0  Female     NaN     NaN        0
# 93704.0                       NaN   2.0    Male     NaN     NaN        0
# 93705.0                      Good  66.0  Female    63.0   165.0        0
# 93706.0                 Very good  18.0    Male    68.0   145.0        0
# 93707.0                      Good  13.0    Male     NaN     NaN        0
# ...                           ...   ...     ...     ...     ...      ...
# 102952.0                Very good  70.0  Female     NaN   117.0      NaN
# 102953.0                  Fair or  42.0    Male    65.0   218.0        0
# 102954.0                     Good  41.0  Female    66.0   150.0        0
# 102955.0                Very good  14.0  Female     NaN     NaN        0
# 102956.0                     Good  38.0    Male    69.0   250.0        0
#
#           pulse  cholesterol_mgdl
# SEQN
# 93703.0     NaN               NaN
# 93704.0     NaN               NaN
# 93705.0    52.0             157.0
# 93706.0    82.0             148.0
# 93707.0   100.0             189.0
# ...         ...               ...
# 102952.0   68.0             119.0
# 102953.0   78.0             182.0
# 102954.0   78.0             172.0
# 102955.0   74.0             150.0
# 102956.0   76.0             163.0
#
# [8366 rows x 8 columns]

# %% [markdown]
# ## Ordenamiento

# %%
#Seleccionando un sub_conjunto de columnas
(
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )
    .rename_columns(
        {
            'age_in_years_at_screening':"age",
            'current_selfreported_height_inches':"height",
            'current_selfreported_weight_pounds':"weight",
            'doctor_told_you_have_diabetes':"diabetes",
            '60_sec_pulse30_sec_pulse2':"pulse",
            'total_cholesterol_mgdl':"cholesterol_mgdl"
        }
    )
    .replace(
        {
            'height':{
                9999:np.nan,
                7777:np.nan
            },
            'weight':{
                9999:np.nan,
                7777:np.nan
            },
            'diabetes':{
                'Borderline':np.nan
            }
        }
    )
    .missing.sort_variables_by_missingness()
)
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#           height  weight general_health_condition  cholesterol_mgdl  pulse  \
# SEQN
# 93703.0      NaN     NaN                      NaN               NaN    NaN
# 93704.0      NaN     NaN                      NaN               NaN    NaN
# 93705.0     63.0   165.0                     Good             157.0   52.0
# 93706.0     68.0   145.0                Very good             148.0   82.0
# 93707.0      NaN     NaN                     Good             189.0  100.0
# ...          ...     ...                      ...               ...    ...
# 102952.0     NaN   117.0                Very good             119.0   68.0
# 102953.0    65.0   218.0                  Fair or             182.0   78.0
# 102954.0    66.0   150.0                     Good             172.0   78.0
# 102955.0     NaN     NaN                Very good             150.0   74.0
# 102956.0    69.0   250.0                     Good             163.0   76.0
#
#          diabetes   age  gender
# SEQN
# 93703.0         0   2.0  Female
# 93704.0         0   2.0    Male
# 93705.0         0  66.0  Female
# 93706.0         0  18.0    Male
# 93707.0         0  13.0    Male
# ...           ...   ...     ...
# 102952.0      NaN  70.0  Female
# 102953.0        0  42.0    Male
# 102954.0        0  41.0  Female
# 102955.0        0  14.0  Female
# 102956.0        0  38.0    Male
#
# [8366 rows x 8 columns]

# %% [markdown]
# Ahora ordenamos nuestro data frame con respecto de las variables que tienen mayor numero de valores faltantes, lo que se traduce al siguiente orden:
# - height
# - weight
# - general_health_condition
# - cholesterol_mgdl
# - pulse
# - diabetes
# - age
# - gender

# %% [markdown]
# ## Eliminando valores nulos en "diabetes"

# %%
#Seleccionando un sub_conjunto de columnas
(
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )
    .rename_columns(
        {
            'age_in_years_at_screening':"age",
            'current_selfreported_height_inches':"height",
            'current_selfreported_weight_pounds':"weight",
            'doctor_told_you_have_diabetes':"diabetes",
            '60_sec_pulse30_sec_pulse2':"pulse",
            'total_cholesterol_mgdl':"cholesterol_mgdl"
        }
    )
    .replace(
        {
            'height':{
                9999:np.nan,
                7777:np.nan
            },
            'weight':{
                9999:np.nan,
                7777:np.nan
            },
            'diabetes':{
                'Borderline':np.nan
            }
        }
    )
    .missing.sort_variables_by_missingness()
    .dropna(
        subset=["diabetes"],
        how='any'   
        #Eliminación en cualquier valor nulo de diabetes
    )
)
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#           height  weight general_health_condition  cholesterol_mgdl  pulse  \
# SEQN
# 93703.0      NaN     NaN                      NaN               NaN    NaN
# 93704.0      NaN     NaN                      NaN               NaN    NaN
# 93705.0     63.0   165.0                     Good             157.0   52.0
# 93706.0     68.0   145.0                Very good             148.0   82.0
# 93707.0      NaN     NaN                     Good             189.0  100.0
# ...          ...     ...                      ...               ...    ...
# 102951.0     NaN     NaN                      NaN               NaN    NaN
# 102953.0    65.0   218.0                  Fair or             182.0   78.0
# 102954.0    66.0   150.0                     Good             172.0   78.0
# 102955.0     NaN     NaN                Very good             150.0   74.0
# 102956.0    69.0   250.0                     Good             163.0   76.0
#
#          diabetes   age  gender
# SEQN
# 93703.0         0   2.0  Female
# 93704.0         0   2.0    Male
# 93705.0         0  66.0  Female
# 93706.0         0  18.0    Male
# 93707.0         0  13.0    Male
# ...           ...   ...     ...
# 102951.0        0   4.0    Male
# 102953.0        0  42.0    Male
# 102954.0        0  41.0  Female
# 102955.0        0  14.0  Female
# 102956.0        0  38.0    Male
#
# [8187 rows x 8 columns]

# %% [markdown]
# ## Transformación de tipo (columnas)

# %%
#Seleccionando un sub_conjunto de columnas
(
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )
    .rename_columns(
        {
            'age_in_years_at_screening':"age",
            'current_selfreported_height_inches':"height",
            'current_selfreported_weight_pounds':"weight",
            'doctor_told_you_have_diabetes':"diabetes",
            '60_sec_pulse30_sec_pulse2':"pulse",
            'total_cholesterol_mgdl':"cholesterol_mgdl"
        }
    )
    .replace(
        {
            'height':{
                9999:np.nan,
                7777:np.nan
            },
            'weight':{
                9999:np.nan,
                7777:np.nan
            },
            'diabetes':{
                'Borderline':np.nan
            }
        }
    )
    .missing.sort_variables_by_missingness()
    .dropna(
        subset=["diabetes"],
        how='any'   
        #Eliminación en cualquier valor nulo de diabetes
    )
    .transform_column(
        column_name = "diabetes",
        function = lambda s:s.astype(int),
        #Para que nos regrese una serie y no un
        #elemento
        elementwise = False    
    )
)
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#           height  weight general_health_condition  cholesterol_mgdl  pulse  \
# SEQN
# 93703.0      NaN     NaN                      NaN               NaN    NaN
# 93704.0      NaN     NaN                      NaN               NaN    NaN
# 93705.0     63.0   165.0                     Good             157.0   52.0
# 93706.0     68.0   145.0                Very good             148.0   82.0
# 93707.0      NaN     NaN                     Good             189.0  100.0
# ...          ...     ...                      ...               ...    ...
# 102951.0     NaN     NaN                      NaN               NaN    NaN
# 102953.0    65.0   218.0                  Fair or             182.0   78.0
# 102954.0    66.0   150.0                     Good             172.0   78.0
# 102955.0     NaN     NaN                Very good             150.0   74.0
# 102956.0    69.0   250.0                     Good             163.0   76.0
#
#           diabetes   age  gender
# SEQN
# 93703.0          0   2.0  Female
# 93704.0          0   2.0    Male
# 93705.0          0  66.0  Female
# 93706.0          0  18.0    Male
# 93707.0          0  13.0    Male
# ...            ...   ...     ...
# 102951.0         0   4.0    Male
# 102953.0         0  42.0    Male
# 102954.0         0  41.0  Female
# 102955.0         0  14.0  Female
# 102956.0         0  38.0    Male
#
# [8187 rows x 8 columns]

# %% [markdown]
# LISTO YA PODRÍAMOS EMPEZAR A TRABAJARLO.
#
# Primero guardemoslo en un conjunto de datos.

# %%
#Seleccionando un sub_conjunto de columnas
nhanes_df = (
    nhanes_raw_df
    .select_columns(
        'general_health_condition',
        'age_in_years_at_screening',
        'gender',
        'current_selfreported_height_inches',
        'current_selfreported_weight_pounds',
        'doctor_told_you_have_diabetes',
        '60_sec_pulse30_sec_pulse2',
        'total_cholesterol_mgdl'
    )
    .rename_columns(
        {
            'age_in_years_at_screening':"age",
            'current_selfreported_height_inches':"height",
            'current_selfreported_weight_pounds':"weight",
            'doctor_told_you_have_diabetes':"diabetes",
            '60_sec_pulse30_sec_pulse2':"pulse",
            'total_cholesterol_mgdl':"cholesterol_mgdl"
        }
    )
    .replace(
        {
            'height':{
                9999:np.nan,
                7777:np.nan
            },
            'weight':{
                9999:np.nan,
                7777:np.nan
            },
            'diabetes':{
                'Borderline':np.nan
            }
        }
    )
    .missing.sort_variables_by_missingness()
    .dropna(
        subset=["diabetes"],
        how='any'   
        #Eliminación en cualquier valor nulo de diabetes
    )
    .transform_column(
        column_name = "diabetes",
        function = lambda s:s.astype(int),
        #Para que nos regrese una serie y no un
        #elemento
        elementwise = False    
    )
)
nhanes_df
# Out:
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /home/dens/miniforge3/envs/imputacion/lib/python3.9/site-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#           height  weight general_health_condition  cholesterol_mgdl  pulse  \
# SEQN
# 93703.0      NaN     NaN                      NaN               NaN    NaN
# 93704.0      NaN     NaN                      NaN               NaN    NaN
# 93705.0     63.0   165.0                     Good             157.0   52.0
# 93706.0     68.0   145.0                Very good             148.0   82.0
# 93707.0      NaN     NaN                     Good             189.0  100.0
# ...          ...     ...                      ...               ...    ...
# 102951.0     NaN     NaN                      NaN               NaN    NaN
# 102953.0    65.0   218.0                  Fair or             182.0   78.0
# 102954.0    66.0   150.0                     Good             172.0   78.0
# 102955.0     NaN     NaN                Very good             150.0   74.0
# 102956.0    69.0   250.0                     Good             163.0   76.0
#
#           diabetes   age  gender
# SEQN
# 93703.0          0   2.0  Female
# 93704.0          0   2.0    Male
# 93705.0          0  66.0  Female
# 93706.0          0  18.0    Male
# 93707.0          0  13.0    Male
# ...            ...   ...     ...
# 102951.0         0   4.0    Male
# 102953.0         0  42.0    Male
# 102954.0         0  41.0  Female
# 102955.0         0  14.0  Female
# 102956.0         0  38.0    Male
#
# [8187 rows x 8 columns]

# %% [markdown]
# Con esto terminamos la clase y el procesamiento de datos desde 0, para tener un conjunto de datos y explorar sus valores faltantes.
#
# Resumen:
#
# - En esta clase realizamos todo el procesamiento de datos para tener un conjunto y así explorar e imputar los valores faltantes.
#
# - Cambiamos los nombres de las columnas para que fuera más sencillo recordarlos y utilizarlos.
#
# - Cambiamos la codificación de valores faltantes a un formato adecuado; es decir los representamos como lo que en verdad son: VALORES FALTANTES.
#
# - Ordenamos el conjunto de datos de tal manera que nos pudiera decir que variables poseen mayor cantidad de valores faltantes.
#
# - Eliminamos observaciones del Data Set para una columna en la cual no había tantos valores  faltantes, es decir su proporción de valores faltantes era muy baja.
#
# - Finalmente transformamos una columna que tenía un tipo inadecuado para su contenido (tipo objeto), pero sabíamos que esta columna era de tipo numérico.
#
#
# En resumen todo este procesamiento nos ayudará a que tengamos la información en una forma adecuada.
